# %% [markdown]
# # Intro

# %% [markdown]
# Des: Who is leaving and why? <br/>
# Des: Close to regresion but here, Y is a categorical value and not continuous <br/>
# Tip: All Xs should be continuous, or converted to continuous

# %% [markdown]
# ## Where do we use it?

# %% [markdown]
# - predict a disease
# - chance of mortality base of a situation
# - halting a subscription
# - purchase
# - failure of a product

# %% [markdown]
# ## Some Tips

# %% [markdown]
# Tip: target should be category (or better, binary) <br/>
# Tip: we need the probability of prediction <br/>
# Tip: we need a linear decition boundary (line or even polynimial) <br/>
# Tip: we need to understand th impact of features (theta is coloser to 0 or is high)

# %% [markdown]
# # Logistic Regression VS Linear Regression

# %% [markdown]
# Des: We use of sigmoind to calculate err and fitting a curve line(sigmoind curve) for better analusis <br/>
# Tip: In fact, we neet to use sigmoid trick in logistic regression method to obtain the thethas that have least error! <br/>
# Guide: ![Screenshot (261).png](attachment:9b0b83a1-a7d1-4963-abfe-cf614b150e6c.png)

# %% [markdown]
# # Logistic Regression Training

# %% [markdown]
# #### Step One: Define Cost Function

# %% [markdown]
# 1. initial θ
# 2. calculate ŷ = σ(θ^T(X)) for a customer
# 3. compare the output of ŷ with actual output of customer, y, and record it as error
# 4. calculate the error for all customers
# 5. change the θ to reduce the **cost**
# 6. go back to step 2
# ##### Guid:
# ![Screenshot (265).png](attachment:d541cbbc-26a8-4d90-bf38-c45811efe990.png)

# %% [markdown]
# ### Step Two: Minimize The Cost Function

# %% [markdown]
# * Solution One: Can be done via derivative but its difficult
# Guide: ![Screenshot (267).png](attachment:3ff5ed1c-21b8-4b8a-aa32-52f9501e43a3.png)

# %% [markdown]
# * Solution Two: use of Gradient Descent (iterative technique) <br/>
# Guid: ![Screenshot (270).png](attachment:dce7f69f-154c-4182-83f3-8617ab609232.png)
