# %% [markdown]
# ## Intro

# %% [markdown]
# ##### درواقع بطور درخت واری به کلاس و یا طبقه حاصل میرسن

# %% [markdown]
# ## Building

# %% [markdown]
# ##### درواقع میشه گفت تلاش ما بر این باید بشه که ترتیب پرسیدن سوالها برای رسیدن به جواب رو پیدا کنیم اینکه بطور اصولی کدوم سوال رو بپرسیم اول
# ##### حتی میتونیم بعضی سوالارو کلا بلاک کنیم بدلیل کم اهمیت بودن و غیره
# ##### و باید درواقع تست کنیم فیلدها و دومین اکسپرت هارو که اول کدوم رو بپرسیم اسکور بهتری نصیبمون خواهد شد
# ##### باید ناخالصی هارو کم کنیم و باید انتروپی رو به کمترین عدد برسونیم
# ##### رو گزاشتیم چقدر سطح از اطلاعاتمون قراره بالا بره if بعد از اینکه به عنوان مثال
# ##### هرکدوم رو حساب بکنیم و در نهایت ببینیم بهترین درختمون چی میتونه باشهinformation gain (IG) درواقع باید
# ##### Entropy(E) formula => H(S) = - (P(B) log2 P(B) + P(A) log2 P(A)) -> P(B) = B/N , P(A) = A/N -> H(S) = −i=1∑n​pi​log2​(pi​)
# ##### Guid:![Screenshot (253).png](attachment:34024383-76ee-4ec5-9c0c-fb659392b204.png)
